# %%
import pandas as pd
import numpy as np

# %%
#Set max row display to 1000
pd.set_option('display.max_row', 1000)

# %%
Jan2021data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2021-01-02/visualisations/listings.csv')
Dec2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-12-12/visualisations/listings.csv')
Nov2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-11-03/visualisations/listings.csv')
Oct2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-10-09/visualisations/listings.csv')
Sep2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-09-09/visualisations/listings.csv')
Aug2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-08-18/visualisations/listings.csv')
Jul2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-07-09/visualisations/listings.csv')
Jun2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-06-08/visualisations/listings.csv')
May2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-05-07/visualisations/listings.csv')
Apr2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-04-09/visualisations/listings.csv')
Mar2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-03-16/visualisations/listings.csv')
Feb2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-02-14/visualisations/listings.csv')
Jan2020data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2020-01-07/visualisations/listings.csv')
Dec2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-12-07/visualisations/listings.csv')
Nov2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-11-03/visualisations/listings.csv')
Oct2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-10-15/visualisations/listings.csv')
Sep2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-09-14/visualisations/listings.csv')
Aug2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-08-08/visualisations/listings.csv')
Jul2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-07-08/visualisations/listings.csv')
Jun2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-06-04/visualisations/listings.csv')
May2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-05-06/visualisations/listings.csv')
Apr2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-04-08/visualisations/listings.csv')
Mar2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-03-07/visualisations/listings.csv')
Feb2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-02-04/visualisations/listings.csv')
Jan2019data = pd.read_csv('http://data.insideairbnb.com/canada/on/toronto/2019-01-13/visualisations/listings.csv')

# %%
Jan2021data['date_compiled'] = pd.Timestamp('2021-01-02')
Jan2021data.tail(5)
# Out:
#              id                                               name    host_id  \
# 18260  47376260   Private Ensuite room, Comfy Guest House, Toronto     138145
# 18261  47376858  Modern Nice and Cozy 3Bedroom House in Scarbor...   61575224
# 18262  47377779                   Private Bedroom Downtown Toronto  317648405
# 18263  47389938  2 Bedrooms, 1 Bathroom YONGE & SHEPPARD - YS25FL1   12742095
# 18264  47390017  Lakeview Condo, CN Tower, Free Parking, Mthly ...   91170750
#
#                host_name  neighbourhood_group  \
# 18260  Comfy Guest House                  NaN
# 18261               Sean                  NaN
# 18262                Dan                  NaN
# 18263         Emil & Sue                  NaN
# 18264              Yawen                  NaN
#
#                              neighbourhood  latitude  longitude  \
# 18260                            Moss Park  43.66206  -79.36938
# 18261                               Woburn  43.77640  -79.22799
# ...

# %%
Dec2020data['date_compiled'] = pd.Timestamp('2020-12-12')
Dec2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 18548  46970103              Elegant House near Yonge and Sheppard   19657311
# 18549  46972809      Master Bedroom Queen St West Downtown Toronto  199185278
# 18550  46973070           Newly Renovated Private & Cozy 3rd Floor  379361883
# 18551  46974551  Luxury Family Home in one of Toronto's Best Areas  140468739
# 18552  46982295                                        生活套房公寓一卧公寓房  151117050
#
#              host_name  neighbourhood_group  \
# 18548  Gloria Geum Lee                  NaN
# 18549            Jason                  NaN
# 18550          Krystal                  NaN
# 18551           Eugene                  NaN
# 18552          Adriana                  NaN
#
#                            neighbourhood  latitude  longitude  \
# 18548                   Lansing-Westgate  43.75710  -79.42384
# 18549                  Trinity-Bellwoods  43.64682  -79.40736
# ...

# %%
Nov2020data['date_compiled'] = pd.Timestamp('2020-11-03')
Nov2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 18801  46197136      SPECIAL RATE!-1 bed/1 bth-Furnished-300 Front  169697179
# 18802  46198668         Private Apt 5-Star LocationDowntownToronto  311805447
# 18803  46200413  Super Cozy Private Apartment Downtown TO Smart TV  311805447
# 18804  46200770           Cozy Bedroom, Downtown Toronto, Smart TV  372316210
# 18805  46201677    Cozy Private Bedroom, Smart TV 15min to Airport  341626040
#
#        host_name  neighbourhood_group                      neighbourhood  \
# 18801  DelSuites                  NaN  Waterfront Communities-The Island
# 18802    Anthony                  NaN               Kensington-Chinatown
# 18803    Anthony                  NaN               Kensington-Chinatown
# 18804        Ben                  NaN               Kensington-Chinatown
# 18805       Jean                  NaN                 Caledonia-Fairbank
#
# ...

# %%
Oct2020data['date_compiled'] = pd.Timestamp('2020-10-09')
Oct2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 18741  45785334  Bright & Luxurious 1 Bdr-Apt  In Heart of Toronto    1023135
# 18742  45786222     3 Cozy Bedrooms, Detached home, 3 Free Parking  371188170
# 18743  45786961                                Stunning View Condo  371195218
# 18744  45789233   30% OFF Private Bedroom, Queen Size Bed, Toronto  304805850
# 18745  45789708     Private Apartment Amazing Downtown TO Location  344709977
#
#       host_name  neighbourhood_group           neighbourhood  latitude  \
# 18741       Sha                  NaN          Yonge-Eglinton  43.70703
# 18742     Grace                  NaN        Newtonbrook East  43.79075
# 18743     Nikta                  NaN         Bayview Village  43.76668
# 18744    Daniel                  NaN  Corso Italia-Davenport  43.67330
# 18745     James                  NaN                 Niagara  43.64481
#
# ...

# %%
Sep2020data['date_compiled'] = pd.Timestamp('2020-09-09')
Sep2020data.tail(5)
# Out:
#              id                                  name    host_id host_name  \
# 19338  45348297   Studio Condo in Downtown Toronto #5  342316738     Davar
# 19339  45351124            budget friendly nice place  342346982      Edip
# 19340  45351175        affordable, long term place :)  342346982      Edip
# 19341  45351235       Studio Unit with a nice view :)  342346982      Edip
# 19342  45351322  Luxury Studio Condo Amazing LakeView   38189462   Frankie
#
#        neighbourhood_group                      neighbourhood   latitude  \
# 19338                  NaN              Church-Yonge Corridor  43.649440
# 19339                  NaN                Mount Pleasant West  43.699408
# 19340                  NaN                     Yonge-St.Clair  43.693933
# 19341                  NaN                     Yonge-Eglinton  43.706643
# 19342                  NaN  Waterfront Communities-The Island  43.642040
#
# ...

# %%
Aug2020data['date_compiled'] = pd.Timestamp('2020-08-18')
Aug2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 19570  44952208  Amazing 2 Bedroom Suite in home - Private Entr...  362188889
# 19571  44955917  FOODPV Rm2x/Toronto Downtown Private Bath/Entr...  291533774
# 19572  44956441  1 BR/1BA Condo with Balcony, High Floor near T...  263009685
# 19573  44958080      Family style 1+Den condo for reasonable price  162975635
# 19574  44963429  Cosy apartment in Beaches/Leslieville (short t...   71296587
#
#          host_name  neighbourhood_group                      neighbourhood  \
# 19570         Eric                  NaN                       Clanton Park
# 19571         Davy                  NaN               Kensington-Chinatown
# 19572     Adrienne                  NaN  Waterfront Communities-The Island
# 19573       Manasa                  NaN                       Clanton Park
# 19574  Christopher                  NaN                  Greenwood-Coxwell
#
# ...

# %%
Jul2020data['date_compiled'] = pd.Timestamp('2020-07-09')
Jul2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 20521  44138040            Jr One bedroom Fully Furnished Condo #7  342316738
# 20522  44138147                   Sunset soothes, mornings dictate   67926033
# 20523  44138518                           Small Semi-detached home  352603587
# 20524  44138982     Deluxe11 - Platinum- 2 Bed 2 Bath Luxury Suite  334021955
# 20525  44139778  Downtown Annex rooftop retreat-Covid free clea...    7788565
#
#        host_name  neighbourhood_group             neighbourhood  latitude  \
# 20521      Davar                  NaN     Church-Yonge Corridor  43.64936
# 20522  Margarita                  NaN  Edenbridge-Humber Valley  43.65986
# 20523      Jason                  NaN           South Riverdale  43.66773
# 20524     Thampi                  NaN                   Niagara  43.64468
# 20525       Dino                  NaN                     Annex  43.66880
#
# ...

# %%
Jun2020data['date_compiled'] = pd.Timestamp('2020-06-08')
Jun2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 21161  43708277                       Lawrence Park Executive Home   63141512
# 21162  43708692           Brand New Private Room Yonge & Wellesley  290388456
# 21163  43709791             Beautiful luxurious house by lakeshore   30305712
# 21164  43710831    *NEW* Breathtaking, Large, Private, Corner Unit   30671009
# 21165  43712409  Fully Furnished Premium Condo Yonge & Sheppard...  110986914
#
#                  host_name  neighbourhood_group  \
# 21161               Alison                  NaN
# 21162              Wenying                  NaN
# 21163                Elina                  NaN
# 21164            Margarita                  NaN
# 21165  Executive Furnished                  NaN
#
#                              neighbourhood   latitude  longitude  \
# 21161                  Lawrence Park North  43.730395 -79.394289
# 21162                  Bay Street Corridor  43.665091 -79.384862
# ...

# %%
May2020data['date_compiled'] = pd.Timestamp('2020-05-07')
May2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 21766  43372389  30% OFF Cozy Bedroom Easy Public Transit, Toronto  326152628
# 21767  43374755                             Exclusive luxury condo  154950119
# 21768  43374824  3 min Walk to subway, Plain but with all you n...  243664501
# 21769  43374905  Newly Renovated 2 Bedroom Luxury Condo WithPar...  180063042
# 21770  43375031  High Park 630 sqr ft. Basement w/separate entr...  292527083
#
#       host_name  neighbourhood_group        neighbourhood   latitude  \
# 21766      Hugo                  NaN   Caledonia-Fairbank  43.686280
# 21767     Elina                  NaN  North St.James Town  43.671680
# 21768     Mooim                  NaN      Willowdale East  43.761332
# 21769     Erdem                  NaN           Henry Farm  43.773690
# 21770    Weiyun                  NaN      High Park North  43.660090
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
Apr2020data['date_compiled'] = pd.Timestamp('2020-04-09')
Apr2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 22420  43140581      Ent District 2BDR Style + Parking + Amenities  266939395
# 22421  43140887    01 room around York U Subway Masks are provided   43488381
# 22422  43142361  New listing! Bright, Spacious High Park Apartment    4260847
# 22423  43143239                               14 York Street Condo  259270206
# 22424  43144017   Trendy stylish loft on king W close to hospitals   16093144
#
#       host_name  neighbourhood_group                      neighbourhood  \
# 22420    Curtis                  NaN  Waterfront Communities-The Island
# 22421   Runying                  NaN            York University Heights
# 22422     David                  NaN                    High Park North
# 22423   Jasmine                  NaN  Waterfront Communities-The Island
# 22424     Walid                  NaN                            Niagara
#
# ...

# %%
Mar2020data['date_compiled'] = pd.Timestamp('2020-03-16')
Mar2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 22999  42914765   Diamond suite-- No cleaning fee + free breakfast  167034435
# 23000  42915363   STERILIZED CLEAN - Fashion District Luxury Condo  341738429
# 23001  42915787   Lovely Cosy and private space  to feel like home  321259702
# 23002  42916243  Comfy bunkbed in a shared room in Scarborough TTC  327456656
# 23003  42917781                          House in downtown Toronto  316319923
#
#        host_name  neighbourhood_group                      neighbourhood  \
# 22999      Kevin                  NaN                          Moss Park
# 23000     Daniel                  NaN  Waterfront Communities-The Island
# 23001  Alejandra                  NaN                        New Toronto
# 23002     Gevorg                  NaN                            Malvern
# 23003      Peter                  NaN                          Moss Park
#
# ...

# %%
Feb2020data['date_compiled'] = pd.Timestamp('2020-02-14')
Feb2020data.tail(5)
# Out:
#              id                                       name    host_id  \
# 23393  42279466                Luxurious modern condo room  335942960
# 23394  42280836                   Cozy House in North York  294307289
# 23395  42281530  Your one stopover to a chilled apartment.   33106212
# 23396  42282147                           Traveller’s spot  122215671
# 23397  42289607                    Brand new modern studio   20356432
#
#          host_name  neighbourhood_group          neighbourhood   latitude  \
# 23393       Atakan                  NaN       Newtonbrook East  43.787228
# 23394        Walid                  NaN        Willowdale West  43.772508
# 23395        Dovid                  NaN       Newtonbrook West  43.788057
# 23396  Julio Cesar                  NaN          Taylor-Massey  43.694363
# 23397      Tasawar                  NaN  Church-Yonge Corridor  43.656841
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
Jan2020data['date_compiled'] = pd.Timestamp('2020-01-07')
Jan2020data.tail(5)
# Out:
#              id                                               name    host_id  \
# 23519  41346460  Bright, Renovated Etobicoke Home: 15m to Downtown  252562067
# 23520  41347750   ★☼Budget Private Room Shared Kitchen & Living RM   23472830
# 23521  41348291                               Quite space to relax  270056921
# 23522  41348626    Loft Style King Street 2 Bedroom - Free Parking  224508343
# 23523  41351232                       Comfort room on the Danforth   98407572
#
#         host_name  neighbourhood_group                      neighbourhood  \
# 23519  Angel Host                  NaN         Islington-City Centre West
# 23520    Benjamin                  NaN                  East End-Danforth
# 23521     Shaydon                  NaN                        Regent Park
# 23522       Brian                  NaN  Waterfront Communities-The Island
# 23523     Michael                  NaN                           Danforth
#
# ...

# %%
Dec2019data['date_compiled'] = pd.Timestamp('2019-12-07')
Dec2019data.tail(5)
# Out:
#              id                                              name    host_id  \
# 23392  40647107                                            Anna小屋  212513433
# 23393  40647659          Artsy Bed & Private Bathroom in Downtown   16057524
# 23394  40650244    4 LOFTS- 6000 SQ FT-2-15 Bedrooms + Party Room    9443058
# 23395  40650884  4 Bed/8 ppl Lux Suite⭐CN Tower View⭐FREE Parking  310253541
# 23396  40651493  Spacious Room 3-Min Walk to Subway (Female Only)  145242773
#
#              host_name  neighbourhood_group  \
# 23392             Anna                  NaN
# 23393             Jenn                  NaN
# 23394  Kristle &Faisal                  NaN
# 23395              Sam                  NaN
# 23396              Mel                  NaN
#
#                            neighbourhood   latitude  longitude  \
# 23392         Islington-City Centre West  43.632224 -79.518382
# 23393                          Moss Park  43.657150 -79.354760
# ...

# %%
Nov2019data['date_compiled'] = pd.Timestamp('2019-11-03')
Nov2019data.tail(5)
# Out:
#              id                                               name    host_id  \
# 22723  39820000                       New home near Subway station  306348423
# 22724  39820494   Minimalist cozy place - Near to public transport  110925975
# 22725  39820779   Scarborough cozy basement with separate entrance  252654875
# 22726  39822833  clean spacious 2 bd unit with lake/cn tower vi...   80537662
# 22727  39823462    5 Bedrooms + Large Detached Home - WIFI/Laundry  154959193
#
#       host_name  neighbourhood_group                      neighbourhood  \
# 22723       Ava                  NaN                         Henry Farm
# 22724  Gabriela                  NaN                   Woodbine-Lumsden
# 22725   Tsering                  NaN                            Bendale
# 22726    Casper                  NaN  Waterfront Communities-The Island
# 22727     Vasim                  NaN                           Milliken
#
# ...

# %%
Oct2019data['date_compiled'] = pd.Timestamp('2019-10-15')
Oct2019data.tail(5)
# Out:
#              id                                               name    host_id  \
# 22211  39361273  Spectacular 2BR Executive Suite Financial Dist...  302339554
# 22212  39361355                   Great full apartment in downtown  302338940
# 22213  39363059    Modern 2 BDR Condo - in the heart of DT Toronto  211673110
# 22214  39363272    Bright and beautiful one bed condo - waterfront  302346483
# 22215  39367185               Beautiful Stay in North York Toronto  302387592
#
#       host_name  neighbourhood_group                      neighbourhood  \
# 22211      Andy                  NaN                Bay Street Corridor
# 22212   Michael                  NaN              Church-Yonge Corridor
# 22213    Guobin                  NaN  Waterfront Communities-The Island
# 22214  Charline                  NaN  Waterfront Communities-The Island
# 22215    Johnny                  NaN               Downsview-Roding-CFB
#
# ...

# %%
Sep2019data['date_compiled'] = pd.Timestamp('2019-09-14')
Sep2019data.tail(5)
# Out:
#              id                                              name    host_id  \
# 21895  38607091      One bedroom Private Quiet Comfy Midtown Apt.  290496503
# 21896  38607568            NEWLY RENOVATED ANNEX 3 BEDROOM BEAUTY   20379553
# 21897  38608462  2 bedroom basement Near Airport & Humber College  162875913
# 21898  38609448             Bedroom near Airport & Humber College  162875913
# 21899  38610028   Clean spacious bedrooms w lots of natural light   56766378
#
#       host_name  neighbourhood_group                      neighbourhood  \
# 21895      Emre                  NaN                Mount Pleasant East
# 21896       Joy                  NaN                              Annex
# 21897  Rupinder                  NaN  Mount Olive-Silverstone-Jamestown
# 21898  Rupinder                  NaN  Mount Olive-Silverstone-Jamestown
# 21899     Sahar                  NaN                Mount Pleasant West
#
#        latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
Aug2019data['date_compiled'] = pd.Timestamp('2019-08-08')
Aug2019data.tail(5)
# Out:
#              id                                               name    host_id  \
# 21612  37571177                                  Friendly bachelor  273279554
# 21613  37571468                            Queen Bed in Stockyards  283849803
# 21614  37578291  ❤️HighRise Classy Condo  in Biz District by Hi...  275038623
# 21615  37579902   ❤️Penthouse Amazing View in Core Biz District TO  275038623
# 21616  37591207           Modern private room in Downtown Toronto!   39720022
#
#       host_name  neighbourhood_group                        neighbourhood  \
# 21612     Mitra                  NaN                     Newtonbrook East
# 21613     James                  NaN                        Junction Area
# 21614    Robert                  NaN                  Bay Street Corridor
# 21615    Robert                  NaN                  Bay Street Corridor
# 21616     Azita                  NaN  Dovercourt-Wallace Emerson-Junction
#
# ...

# %%
Jul2019data['date_compiled'] = pd.Timestamp('2019-07-08')
Jul2019data.tail(5)
# Out:
#              id                                               name    host_id  \
# 21307  36505368         Modern, elegant condo with panoramic views  274460050
# 21308  36505571           DOWNTOWN TORONTO CITY VIEW LUXURY SUITE.  274460567
# 21309  36506892                              A place by the Ravine  240720596
# 21310  36511507  Prime Trinity Bellwoods Park location near Que...   14383797
# 21311  36514152  Bright Beautiful Brilliant 2 Bedroom nearby su...  273422669
#
#        host_name  neighbourhood_group                      neighbourhood  \
# 21307       Leon                  NaN                Bay Street Corridor
# 21308  Christian                  NaN  Waterfront Communities-The Island
# 21309    Hidulfa                  NaN                Clairlea-Birchmount
# 21310     Andrea                  NaN                  Trinity-Bellwoods
# 21311       Gary                  NaN                         Henry Farm
#
# ...

# %%
Jun2019data['date_compiled'] = pd.Timestamp('2019-06-04')
Jun2019data.tail(5)
# Out:
#              id                                               name    host_id  \
# 20764  35373390                Kensington Market Cozy Private Unit  224566888
# 20765  35376137  newly renovated single room in heart of dt Tor...  227634512
# 20766  35376802    newly renovated single room heart of dt Toronto  227634512
# 20767  35378234      1 BR Modern Condo - Ent. District, MTCC, Jays  257889901
# 20768  35383772     New Loft Style - Private Terrace, Easy Parking  192794985
#
#       host_name  neighbourhood_group                        neighbourhood  \
# 20764       Ann                  NaN                 Kensington-Chinatown
# 20765    Nicole                  NaN                 Kensington-Chinatown
# 20766    Nicole                  NaN                 Kensington-Chinatown
# 20767      Lily                  NaN    Waterfront Communities-The Island
# 20768    Adrian                  NaN  Dovercourt-Wallace Emerson-Junction
#
# ...

# %%
May2019data['date_compiled'] = pd.Timestamp('2019-05-06')
May2019data.tail(5)
# Out:
#              id                                            name    host_id  \
# 20298  34449599                                 Convenience Hub  121442022
# 20299  34449766     Cozy condo with amazing view of CN Tower <3  260067997
# 20300  34450478        R2: Queen Size Bed Upstairs, Scarborough  109012911
# 20301  34450621      Modern condo in heart of Toronto downtown!  260067997
# 20302  34450758  Fully Furnished 4 Bedroom Upstairs of Bungalow    6110142
#
#       host_name  neighbourhood_group           neighbourhood  latitude  \
# 20298    Birkan                  NaN     Mount Pleasant West  43.71277
# 20299    Sherry                  NaN                 Niagara  43.63760
# 20300     Iouri                  NaN  Tam O'Shanter-Sullivan  43.77689
# 20301    Sherry                  NaN     Bay Street Corridor  43.66689
# 20302     Yusuf                  NaN        Newtonbrook West  43.78661
#
#        longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
Apr2019data['date_compiled'] = pd.Timestamp('2019-04-08')
Apr2019data.tail(5)
# Out:
#              id                                               name    host_id  \
# 20138  33684559    Beautiful 1 bedroom home in Toronto (queen bed)   89113555
# 20139  33685612               DOWNTOWN LUXURY 2BDRM 2BTH + PARKING  170567513
# 20140  33685686  Master Room "Ocean" @ GTA transit hub Yonge Finch  100833811
# 20141  33688362                             Make yourself at home!  176719438
# 20142  33690890  Enjoy Yorkville Skyline (2 bed + 2 bath + Park...   12478688
#
#       host_name  neighbourhood_group                      neighbourhood  \
# 20138     Nelly                  NaN                  Forest Hill North
# 20139   Golsana                  NaN  Waterfront Communities-The Island
# 20140    Rachel                  NaN                   Newtonbrook East
# 20141     Vijay                  NaN                         Henry Farm
# 20142       Ray                  NaN                              Annex
#
# ...

# %%
Mar2019data['date_compiled'] = pd.Timestamp('2019-03-07')
Mar2019data.tail(5)
# Out:
#              id                                    name   host_id host_name  \
# 20031  32869854  Downtown Convenience, Downtown Comfort  98737081    Cassie
# 20032  32870150               The (Hidden by Airbnb) ad   4834923  Geoffrey
# 20033  32870359                    Cozy downtown studio  99988800       Sok
# 20034  32871281                           D&M apartment  10583403  Danijela
# 20035  32872018               Davisville Weekend Airbnb  78297659      Kurt
#
#        neighbourhood_group                      neighbourhood  latitude  \
# 20031                  NaN  Waterfront Communities-The Island  43.63972
# 20032                  NaN                     Yonge-St.Clair  43.69599
# 20033                  NaN                            Niagara  43.64054
# 20034                  NaN                     Yonge-St.Clair  43.69354
# 20035                  NaN                Mount Pleasant West  43.69816
#
# ...

# %%
Feb2019data['date_compiled'] = pd.Timestamp('2019-02-04')
Feb2019data.tail(5)
# Out:
#              id                                               name    host_id  \
# 19880  32109624  Unique, artistic 1 BDR plus Studio on Bloor line!    1408959
# 19881  32112571                CHIC TORONTO LOFT - ST.CLAIR AVE. W   37939368
# 19882  32113035      Amazing 42nd floor city view downtown Toronto   40861890
# 19883  32114055          Hullmark luxury fully furnished apartment  240924961
# 19884  32114298     30 Roehampton luxury fully furnished apartment  240924961
#
#         host_name  neighbourhood_group                        neighbourhood  \
# 19880        Jena                  NaN  Dovercourt-Wallace Emerson-Junction
# 19881           L                  NaN               Corso Italia-Davenport
# 19882  Christelle                  NaN    Waterfront Communities-The Island
# 19883      Howard                  NaN                      Willowdale East
# 19884      Howard                  NaN                  Mount Pleasant West
#
# ...

# %%
Jan2019data['date_compiled'] = pd.Timestamp('2019-01-13')
Jan2019data.tail(5)
# Out:
#              id                                               name    host_id  \
# 19648  31517024   Best Value/$ for family accommodation in Toronto  147933259
# 19649  31517341      Cozy room subway on side next to yonge street  157793742
# 19650  31517380                The studio, with a private washroom  233703816
# 19651  31518185  Trendy split level Apt. w exposed brick &freepark   18413679
# 19652  31518232                Modern One Bedroom Downtown Toronto   99635980
#
#           host_name  neighbourhood_group        neighbourhood   latitude  \
# 19648         Ayman                  NaN  Clairlea-Birchmount  43.701751
# 19649   Amirhossein                  NaN      Willowdale West  43.777792
# 19650        Pierce                  NaN    Woodbine Corridor  43.677890
# 19651        Nicole                  NaN      North Riverdale  43.669072
# 19652  Gilda Suites                  NaN              Niagara  43.638046
#
# ...

# %%
#Concat all dfs into one

df = pd.concat([Jan2021data, Dec2020data, Nov2020data, Oct2020data, Sep2020data, Aug2020data, Jul2020data, Jun2020data, May2020data, Apr2020data, Mar2020data, Feb2020data, Jan2020data, Dec2019data, Nov2019data, Oct2019data, Sep2019data, Aug2019data, Jul2019data, Jun2019data, May2019data, Apr2019data, Mar2019data, Feb2019data, Jan2019data], ignore_index=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 523061 entries, 0 to 523060
# Data columns (total 16 columns):
# id                                523061 non-null int64
# name                              523034 non-null object
# host_id                           523061 non-null int64
# host_name                         522547 non-null object
# neighbourhood                     523061 non-null object
# latitude                          523061 non-null float64
# longitude                         523061 non-null float64
# room_type                         523061 non-null object
# price                             523061 non-null int64
# minimum_nights                    523061 non-null int64
# number_of_reviews                 523061 non-null int64
# last_review                       421792 non-null object
# reviews_per_month                 421792 non-null float64
# calculated_host_listings_count    523061 non-null int64
# availability_365                  523061 non-null int64
# ...

# %%
#Can delete neighbourhood group, as there are zero measurements in this columns

del df['neighbourhood_group']

# %%
df.to_csv(r'C:\Users\jaypa\Documents\Data Projects\AirBNB\AirBNBdata.csv', index = False)
